# %% [markdown]
# Importing the dependencies

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
# Data collection and analysis

df = pd.read_csv('./content/diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
# getting the statistical measures of data

df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  ...  DiabetesPedigreeFunction        Age
# Outcome                           ...
# 0           3.298000  109.980000  ...                  0.429734  31.190000
# 1           4.865672  141.257463  ...                  0.550500  37.067164
#
# [2 rows x 8 columns]

# %%
# Seprating the data and labels

# %%
x = df.drop(columns=['Outcome'], axis =1)
y = df['Outcome']

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# ...

# %%
# data Standarization

scalar = StandardScaler() # create instance of standardscalar

scalar.fit(x)  # fit the data

standarized_data = scalar.transform(x) # transform it into standarized values

# %%
x = standarized_data

# %% [markdown]
# Train  and Train Splitting

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state= 4, stratify = y) # stratify ->divide the date in unformity

# %%
print(x_train.shape, x_test.shape)
# Out:
# (614, 8) (154, 8)

# %% [markdown]
# Model training

# %%
classifier  = svm.SVC(kernel='linear') # SVC - support vector classifier

# %%
# training the model

classifier.fit( x_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# Model Evaluation

# %%
#Finding the Accuracy Score
# Accuracy score on the training data

x_train_predict = classifier.predict(x_train)
training_data_accuracy = accuracy_score(x_train_predict, y_train)

print(training_data_accuracy)
# Out:
# 0.7866449511400652

# %%
#Finding the Accuracy Score
# Accuracy score on the testing data

x_test_predict = classifier.predict(x_test)
testing_data_accuracy = accuracy_score(x_test_predict, y_test)

print(testing_data_accuracy)
# Out:
# 0.7272727272727273

# %% [markdown]
# making an predictive system

# %%
# 4, 110, 92, 0 ,0, 37.6, 0.191, 30, 0

input_data = (4,110,92,0,0,37.6,0.191,30)
#changeing the input data into numpy array

input_data_npArray= np.asarray(input_data)

print(input_data_npArray)

#Reshape the array as we are predicting the for one instances
input_data_reshaped = input_data_npArray.reshape(1, -1)

print(input_data_reshaped)

# Standardize the input data

std_data  = scalar.transform(input_data_reshaped)
print(std_data)

#Make the prediction finally 

prediction = classifier.predict(std_data)
print(prediction)
# Out:
# [  4.    110.     92.      0.      0.     37.6     0.191  30.   ]
# [[  4.    110.     92.      0.      0.     37.6     0.191  30.   ]]
# [[ 0.04601433 -0.34096773  1.18359575 -1.28821221 -0.69289057  0.71168975
#   -0.84827977 -0.27575966]]
# [0]
